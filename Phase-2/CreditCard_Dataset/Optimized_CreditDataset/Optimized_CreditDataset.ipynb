# %%
pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 torchtext==0.12.0 --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu113
# Collecting torch==1.11.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.11.0%2Bcu113-cp38-cp38-linux_x86_64.whl (1637.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.6/1.6 GB 71.5 MB/s eta 0:00:01tcmalloc: large alloc 1636999168 bytes == 0x2360000 @  0x7fba5be9f1e7 0x4d30a0 0x4d312c 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4997a2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.6/1.6 GB 70.9 MB/s eta 0:00:01tcmalloc: large alloc 2046255104 bytes == 0x63c8a000 @  0x7fba5bea0615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x5d8868 0x4997a2 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941
# tcmalloc: large alloc 1636999168 bytes == 0x2360000 @  0x7fba5be9f1e7 0x4d30a0 0x5dede2 0x6758aa 0x4f750a 0x4997a2 0x55cd91 0x5d8941 0x4997a2 0x55cd91 0x5d8941 0x4fe318 0x5da092 0x62042c 0x5d8d8c 0x561f80 0x4fd2db 0x4997c7 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 GB 840.5 kB/s eta 0:00:00
# Collecting torchvision==0.12.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.12.0%2Bcu113-cp38-cp38-linux_x86_64.whl (22.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 40.9 MB/s eta 0:00:00
# Collecting torchaudio==0.11.0
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.11.0%2Bcu113-cp38-cp38-linux_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 12.6 MB/s eta 0:00:00
# Collecting torchtext==0.12.0
#   Downloading torchtext-0.12.0-cp38-cp38-manylinux1_x86_64.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 40.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.11.0+cu113) (4.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0+cu113) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0+cu113) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision==0.12.0+cu113) (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.12.0) (4.64.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0+cu113) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0+cu113) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0+cu113) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision==0.12.0+cu113) (2.10)
# Installing collected packages: torch, torchvision, torchtext, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.14.0
#     Uninstalling torchtext-0.14.0:
#       Successfully uninstalled torchtext-0.14.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.0+cu116
#     Uninstalling torchaudio-0.13.0+cu116:
#       Successfully uninstalled torchaudio-0.13.0+cu116
# Successfully installed torch-1.11.0+cu113 torchaudio-0.11.0+cu113 torchtext-0.12.0 torchvision-0.12.0+cu113

# %%
import scipy
import torch
import matplotlib.pyplot as plt

# %%
# To install Falkon library
# !pip install git+https://github.com/falkonml/falkon.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/falkonml/falkon.git
#   Cloning https://github.com/falkonml/falkon.git to /tmp/pip-req-build-w78ak7e6
#   Running command git clone --filter=blob:none --quiet https://github.com/falkonml/falkon.git /tmp/pip-req-build-w78ak7e6
#   Resolved https://github.com/falkonml/falkon.git to commit e0f35851b00e181d6f2a5c52fc1aa160b1e7b0d6
#   Preparing metadata (setup.py) ... done
# Collecting keopscore@ git+https://github.com/getkeops/keops@ad044a671fdc3c2790b0321f6b9f9b5aa3d220df#subdirectory=keopscore
#   Cloning https://github.com/getkeops/keops (to revision ad044a671fdc3c2790b0321f6b9f9b5aa3d220df) to /tmp/pip-install-a5ghbk0g/keopscore_90a1b71416c94adca74886561c69020d
#   Running command git clone --filter=blob:none --quiet https://github.com/getkeops/keops /tmp/pip-install-a5ghbk0g/keopscore_90a1b71416c94adca74886561c69020d
#   Running command git rev-parse -q --verify 'sha^ad044a671fdc3c2790b0321f6b9f9b5aa3d220df'
#   Running command git fetch -q https://github.com/getkeops/keops ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Running command git checkout -q ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Resolved https://github.com/getkeops/keops to commit ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Collecting pykeops@ git+https://github.com/getkeops/keops@ad044a671fdc3c2790b0321f6b9f9b5aa3d220df#subdirectory=pykeops
#   Cloning https://github.com/getkeops/keops (to revision ad044a671fdc3c2790b0321f6b9f9b5aa3d220df) to /tmp/pip-install-a5ghbk0g/pykeops_86ed9f617e1f4482aee5f4f06fa42e69
#   Running command git clone --filter=blob:none --quiet https://github.com/getkeops/keops /tmp/pip-install-a5ghbk0g/pykeops_86ed9f617e1f4482aee5f4f06fa42e69
#   Running command git rev-parse -q --verify 'sha^ad044a671fdc3c2790b0321f6b9f9b5aa3d220df'
#   Running command git fetch -q https://github.com/getkeops/keops ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Running command git checkout -q ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Resolved https://github.com/getkeops/keops to commit ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.8/dist-packages (from falkon==0.7.5) (1.11.0+cu113)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from falkon==0.7.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from falkon==0.7.5) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from falkon==0.7.5) (1.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/dist-packages (from falkon==0.7.5) (5.4.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.9->falkon==0.7.5) (4.4.0)
# Collecting pybind11
#   Downloading pybind11-2.10.3-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->falkon==0.7.5) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->falkon==0.7.5) (1.2.0)
# Building wheels for collected packages: falkon, keopscore, pykeops
#   Building wheel for falkon (setup.py) ... done
#   Created wheel for falkon: filename=falkon-0.7.5-cp38-cp38-linux_x86_64.whl size=7523182 sha256=d1cd0a0a4efc02e6bcedb6d0fa2629cd0aa997c53d3b83ad2c60011d7f957f5e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-283b8pqo/wheels/40/78/7d/48573e93aab7e41bfa1cd4677963d909f7fbe64930b706b70c
#   Building wheel for keopscore (setup.py) ... done
#   Created wheel for keopscore: filename=keopscore-2.1-py3-none-any.whl size=147541 sha256=42e367dd9dfed028667e8e6c8eae3f1accbf352629867eb6a51eb32095bff973
#   Stored in directory: /root/.cache/pip/wheels/7b/ae/f5/30e7a89adb5ee516d1214872bd69c3a979a6b1a024aae64e6a
#   Building wheel for pykeops (setup.py) ... done
#   Created wheel for pykeops: filename=pykeops-2.1-py3-none-any.whl size=112058 sha256=10c6fa7479dcea6c4f0ed3ec835ba2d13051696bc6981261497824537a1b6588
#   Stored in directory: /root/.cache/pip/wheels/0e/f3/5e/ef6d58318114b7c2855650e1418ec50d0fd03704243d935d95
# Successfully built falkon keopscore pykeops
# Installing collected packages: pybind11, keopscore, pykeops, falkon
# Successfully installed falkon-0.7.5 keopscore-2.1 pybind11-2.10.3 pykeops-2.1

# %%
import falkon
# Out:
# [KeOps] Warning : cuda was detected, but driver API could not be initialized. Switching to cpu only.

# %%
# Drive
from google.colab import drive

# we connect to the drive folder to work with the data stored
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
import os, time

# %%
import numpy as np

import os, time

import torch

from falkon import LogisticFalkon
from falkon.kernels import GaussianKernel
from falkon.options import FalkonOptions
from falkon.gsc_losses import WeightedCrossEntropyLoss

import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

from sklearn import metrics
from scipy.spatial.distance import pdist
from scipy.stats import norm, chi2, rv_continuous, kstest


# UTILS

def candidate_sigma(data, perc=90):
    # this function estimates the width of the gaussian kernel.
    # use on a (small) sample of reference data (standardize first if necessary)
    pairw = pdist(data)
    return round(np.percentile(pairw,perc),1)

'''
def NP2_gen(size, seed):
    # custom function to generate samples of non-resonant new physics events
    if size>10000:
        raise Warning('Sample size is grater than 1000: Generator will not approximate the tail well')
    sample = np.array([])
    #normalization factor                                                                                                                                    
    np.random.seed(seed)
    Norm = 256.*0.25*0.25*np.exp(-2)
    while(len(sample)<size):
        x = np.random.uniform(0,1) #assuming not to generate more than 10 000 events                                                                         
        p = np.random.uniform(0, Norm)
        if p<= 256.*x*x*np.exp(-8.*x):
            sample = np.append(sample, x)
    return sample
'''

class non_res(rv_continuous):

    def _pdf(self, x):

        return 256 * (x**2) * np.exp(- 8 * x)

def nonres_sig(N_S, seed):
    # this function can be used to generate non-resonant signal events.
    
    my_sig = non_res(momtype = 0, a=0, b=1, seed=seed)
    
    sig_sample = my_sig.rvs(size = N_S)
    
    return sig_sample


def get_logflk_config(M,flk_sigma,lam,weight,iter=[100],seed=None,cpu=False):
    # it returns logfalkon parameters
    return {
            'kernel' : GaussianKernel(sigma=flk_sigma),
            'M' : M, #number of Nystrom centers,
            'penalty_list' : lam, # list of regularization parameters,
            'iter_list' : iter, #list of number of CG iterations,
            'options' : FalkonOptions(cg_tolerance=np.sqrt(1e-7), keops_active='no', use_cpu=cpu, debug = False),
            'seed' : seed, # (int or None), the model seed (used for Nystrom center selection) is manually set,
            'loss' : WeightedCrossEntropyLoss(kernel=GaussianKernel(sigma=flk_sigma), neg_weight=weight),
            }


def compute_t(preds,Y,weight):
    # it returns extended log likelihood ratio from predictions
    diff = weight*np.sum(1 - np.exp(preds[Y==0]))
    return 2 * (diff + np.sum(preds[Y==1]))

def trainer(X,Y,flk_config):
    # trainer for logfalkon model
    Xtorch=torch.from_numpy(X)
    Ytorch=torch.from_numpy(Y)
    model = LogisticFalkon(**flk_config)
    model.fit(Xtorch, Ytorch)
    return model.predict(Xtorch).numpy()

def standardize(X):
    # standardize data as in HIGGS and SUSY
    for j in range(X.shape[1]):
        column = X[:, j]

        mean = np.mean(column)
        std = np.std(column)
    
        if np.min(column) < 0:
            column = (column-mean)*1./ std
        elif np.max(column) > 1.0:                                                                                                                                        
            column = column *1./ mean
    
        X[:, j] = column
    
    return X

def return_best_chi2dof(tobs):
    """
    Returns the most fitting value for dof assuming tobs follows a chi2_dof distribution,
    computed with a Kolmogorov-Smirnov test, removing NANs and negative values.
    Parameters
    ----------
    tobs : np.ndarray
        observations
    Returns
    -------
        best : tuple
            tuple with best dof and corresponding chi2 test result
    """
    
    
    dof_range = np.arange(np.nanmedian(tobs) - 10, np.nanmedian(tobs) + 10, 0.1)
    
    ks_tests = []
    
    for dof in dof_range:
        
        test = kstest(tobs, lambda x:chi2.cdf(x, df=dof))[0]
        
        ks_tests.append((dof, test))
        
    ks_tests = [test for test in ks_tests if test[1] != 'nan'] # remove nans
    
    ks_tests = [test for test in ks_tests if test[0] >= 0] # retain only positive dof
        
    best = min(ks_tests, key = lambda t: t[1]) # select best dof according to KS test result
        
    return best

# %%
def emp_zscore(t0,t1):
    if max(t0) <= t1:
        p_obs = 1 / len(t0)
        Z_obs = round(norm.ppf(1 - p_obs),2)
        return Z_obs
    else:
        p_obs = np.count_nonzero(t0 >= t1) / len(t0)
        Z_obs = round(norm.ppf(1 - p_obs),2)
        return Z_obs

def chi2_zscore(t1, dof):
    p = chi2.cdf(float('inf'),dof)-chi2.cdf(t1,dof)
    return norm.ppf(1 - p)

# %%
def err_bar(hist, n_samples):
    
    bins_counts = hist[0]
    bins_limits = hist[1]
    
    x   = 0.5*(bins_limits[1:] + bins_limits[:-1])
    
    bins_width = 0.5*(bins_limits[1:] - bins_limits[:-1])
    err = np.sqrt(np.array(bins_counts)/(n_samples*np.array(bins_width)))
    
    return x, err

# %%
def plot_data(data, label, name=None, dof=None, out_path=None, title=None,
                 density=True, bins=10,
                 c='mediumseagreen', e='darkgreen'):
    """
    Plot reference vs new physics t distribution
    Parameters
    ----------
    data : np.ndarray or list
        (N_toy,) array of observed test statistics
    dof : int 
        degrees of freedom of the chi-squared distribution
    name : string
        filename for the saved figure
    out_path : string, optional
        output path where the figure will be saved. The default is ./fig.
    title : string
        title of the plot
    density : boolean
        True to normalize the histogram, false otherwise.
    bins : int or string, optional
        bins for the function plt.hist(). The default is 'fd'.
    Returns
    -------
    plot
    """
    
 
    plt.figure(figsize=(10,7))
    plt.style.use('classic')
    

    hist = plt.hist(data, bins = bins, color=c, edgecolor=e,
                        density=density, label = str(label))
    x_err, err = err_bar(hist, data.shape[0])
    plt.errorbar(x_err, hist[0], yerr = err, color=e, marker='o', ms=6, ls='', lw=1,
                 alpha=0.7)
    

    plt.ylim(bottom=0)
    
    # results data
    md_t = round(np.median(data), 2)
    if dof:
        z_chi2 = round(chi2_zscore(np.median(data),dof=dof),2)
    
    if dof:
        res = "md t = {} \nZ_chi2 = {}".format(md_t,z_chi2)
    else:
        res = "md t = {}".format(md_t)

    # plot chi2 and set xlim
    if dof:
        chi2_range = chi2.ppf(q=[0.00001,0.999], df=dof)
        x = np.arange(chi2_range[0], chi2_range[1], .05)
        chisq = chi2.pdf(x, df=dof)       
        plt.plot(x, chisq, color='#d7191c', lw=2, label='$\chi^2(${}$)$'.format(dof))
        xlim = (min(chi2_range[0], min(data)-5), max(chi2_range[1], max(data)+5))
        plt.xlim(chi2_range)
    else:
        xlim = (min(data)-5, max(data)+5)
        plt.xlim(xlim)


    if title:
        plt.title(title, fontsize=20)
    
    plt.ylabel('P(t)', fontsize=20)
    plt.xlabel('t', fontsize=20)
    
    # Axes ticks
    ax = plt.gca()
    
    plt.legend(loc ="upper right", frameon=True, fontsize=18)
    
    ax.text(0.75, 0.65, res, color='black', fontsize=12,
        bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=.5'),transform = ax.transAxes)
    
    plt.tight_layout()
    
    if out_path:
        plt.savefig(out_path+"/data_{}.pdf".format(name), bbox_inches='tight')
    
    plt.show()
        
    plt.close()

# %%
def plot_ref_data(ref, data, name=None, dof=None, out_path=None, title=None,
                 density=True, bins=10,
                 c_ref='#abd9e9', e_ref='#2c7bb6', c_sig='#fdae61', e_sig='#d7191c'):
    """
    Plot reference vs new physics t distribution
    Parameters
    ----------
    T_ref : np.ndarray or list
        (N_toy,) array of observed test statistics in the reference hypothesis
    T_sig : np.ndarray or list
        (N_toy,) array of observed test statistics in the New Physics hypothesis
    dof : int 
        degrees of freedom of the chi-squared distribution
    name : string
        filename for the saved figure
    out_path : string, optional
        output path where the figure will be saved. The default is ./fig.
    title : string
        title of the plot
    density : boolean
        True to normalize the histogram, false otherwise.
    bins : int or string, optional
        bins for the function plt.hist(). The default is 'fd'.
    Returns
    -------
    plot
    """
    
 
    plt.figure(figsize=(10,7))
    plt.style.use('classic')
    #set uniform bins across all data points
    bins = np.histogram(np.hstack((ref,data)), bins = bins)[1]
    
    # reference
    hist_ref = plt.hist(ref, bins = bins, color=c_ref, edgecolor=e_ref,
                        density=density, label = 'Reference')
    x_err, err = err_bar(hist_ref, ref.shape[0])
    plt.errorbar(x_err, hist_ref[0], yerr = err, color=e_ref, marker='o', ms=6, ls='', lw=1,
                 alpha=0.7)
    # data
    hist_sig = plt.hist(data, bins = bins, color=c_sig, edgecolor=e_sig,
                        alpha=0.7, density=density, label='Data')
    x_err, err = err_bar(hist_sig, data.shape[0])
    plt.errorbar(x_err, hist_sig[0], yerr = err, color=e_sig, marker='o', ms=6, ls='', lw=1,
                 alpha=0.7)
    

    plt.ylim(bottom=0)
    
    # results data
    md_tref = round(np.median(ref), 2)
    md_tdata = round(np.median(data), 2)
    max_zemp = emp_zscore(ref,np.max(ref))
    zemp = emp_zscore(ref,np.median(data))
    if dof:
        z_chi2 = round(chi2_zscore(np.median(data),dof=dof),2)
    
    if dof:
        res = "md t_ref = {} \nmd t_data = {} \nmax Z_emp = {}  \nZ_emp = {} \nZ_chi2 = {}".format(
            md_tref,
            md_tdata,
            max_zemp,
            zemp,
            z_chi2
        )
    else:
        res = "md tref = {} \nmd tdata = {} \nmax Zemp = {} \nZemp = {}".format(
            md_tref,
            md_tdata,
            max_zemp,
            zemp
        )

    # plot chi2 and set xlim
    if dof:
        chi2_range = chi2.ppf(q=[0.00001,0.999], df=dof)
        #r_len = chi2_range[1] - chi2_range[0]
        x = np.arange(chi2_range[0], chi2_range[1], .05)
        chisq = chi2.pdf(x, df=dof)       
        plt.plot(x, chisq, color='#d7191c', lw=2, label='$\chi^2(${}$)$'.format(dof))
        xlim = (min(chi2_range[0], min(ref)-1), max(chi2_range[1], max(data)+1))
        plt.xlim(xlim)
    else:
        xlim = (min(ref)-1, max(data)+1)
        plt.xlim(xlim)


    if title:
        plt.title(title, fontsize=20)
    
    plt.ylabel('P(t)', fontsize=20)
    plt.xlabel('t', fontsize=20)
    
    # Axes ticks
    ax = plt.gca()
    
    plt.legend(loc ="upper right", frameon=True, fontsize=18)
    
    ax.text(0.75, 0.55, res, color='black', fontsize=12,
        bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=.5'),transform = ax.transAxes)
    
    plt.tight_layout()
    
    if out_path:
        plt.savefig(out_path+"/refdata_{}.pdf".format(name), bbox_inches='tight')
        
    plt.close()

# %%
def get_template_roc_curve(ax, title,fs,random=True):
    
    ax.set_title(title, fontsize=fs)
    ax.set_xlim([-0.01, 1.01])
    ax.set_ylim([-0.01, 1.01])
    
    ax.set_xlabel('False Positive Rate', fontsize=fs)
    ax.set_ylabel('True Positive Rate', fontsize=fs)
    
    if random:
        ax.plot([0, 1], [0, 1],'r--',label="AUC ROC Random = 0.5")
        
def get_template_pr_curve(ax, title,fs, baseline=0.5):
    ax.set_title(title, fontsize=fs)
    ax.set_xlim([-0.01, 1.01])
    ax.set_ylim([-0.01, 1.01])
    
    ax.set_xlabel('Recall (True Positive Rate)', fontsize=fs)
    ax.set_ylabel('Precision', fontsize=fs)
    
    ax.plot([0, 1], [baseline, baseline],'r--',label='AP Random = 0.5')

# %%
def metrics_plots(data_path, output_path, N_0, N0, NS, flk_config, df=10, savefig=True):
  '''
  plotting the AUC ROC, and PR curves
  '''

  weight = N0/N_0
  # loading data
  df = pd.read_csv(data_path)

    
  # dividing the dataset
  fraud_df = df.loc[df['Class'] == 1]
  non_fraud_df = df.loc[df['Class'] == 0]

  dim = 2
  rng = np.random.default_rng(123)

  # Shuffling the data
  df = df.sample(frac=1, random_state=123)
  fraud_df = fraud_df.sample(frac=1,random_state=123)
  non_fraud_df = non_fraud_df.sample(frac=1,random_state=123)

  N0p = rng.poisson(lam=N0)
  NSp = rng.poisson(lam=NS) # if data contains anomalies
  N = N_0 + N0p + NSp

  X = np.zeros(shape=(N,dim))
  X[:N_0+N0p,:] = non_fraud_df[['V11','V14']].sample(n= N_0+N0p, replace=False, random_state=123) # ref and bkg
  X[N_0+N0p:,:] = fraud_df[['V11','V14']].sample(n= NSp, replace=False, random_state=123) # signal
  # initialize labes
  Y = np.zeros(shape=(N,1))
  Y[N_0:,:] = np.ones((N0p+NSp,1)) # flip data labels to one
  X = np.array(X)

  preds = trainer(X,Y,flk_config)

  curve, ax = plt.subplots(2, 1, figsize=(15,10))

  # AUC ROC curve

  FPR_list, TPR_list, threshold = metrics.roc_curve(Y, preds)
  ROC_AUC = metrics.auc(FPR_list, TPR_list)
    
  get_template_roc_curve(ax[0],title='Receiver Operating Characteristic Curve',fs=15)

  ax[0].plot(FPR_list, TPR_list, 'b', label = 'AUC ROC = {0:0.3f}'.format(ROC_AUC))
  ax[0].legend(loc = 'upper left',bbox_to_anchor=(1.05, 1))



  # PR (Precision Recall) curve

  get_template_pr_curve(ax[1], "Precision Recall (PR) Curve", fs=15, baseline = sum(np.array(Y))/len(np.array(Y)))

  precision, recall, threshold = metrics.precision_recall_curve(Y, preds)
  precision=precision[::-1]
  recall=recall[::-1]

  AP = metrics.average_precision_score(Y, preds)

  ax[1].step(recall, precision, 'b', label = 'AP = {0:0.3f}'.format(AP))
  ax[1].legend(loc = 'upper left',bbox_to_anchor=(1.05, 1))
  plt.subplots_adjust(wspace=0.5, hspace=0.8)

  if output_path:
      plt.savefig(output_path+"/metric_plots.pdf", bbox_inches='tight')
    
  plt.close()

# %%
def plot_reconstruction(df, data, weight_data, ref, weight_ref, t_obs, ref_preds,
                        save=False, save_path='', file_name=''):
    '''
    Reconstruction of the data distribution learnt by the model.
    
    df:              (int) chi2 degrees of freedom
    data:            (numpy array, shape (None, n_dimensions)) data training sample (label=1)
    weight_data:     (numpy array, shape (None,)) weights of the data sample (default ones)
    ref:             (numpy array, shape (None, n_dimensions)) reference training sample (label=0)
    weight_ref:      (numpy array, shape (None,)) weights of the reference sample
    tau_OBS:         (float) value of the tau term after training
    output_tau_ref:  (numpy array, shape (None, 1)) tau prediction of the reference training sample after training
    feature_labels:  (list of string) list of names of the training variables
    bins_code:       (dict) dictionary of bins edge for each training variable (bins_code.keys()=feature_labels)
    xlabel_code:     (dict) dictionary of xlabel for each training variable (xlabel.keys()=feature_labels)
    ymax_code:       (dict) dictionary of maximum value for the y axis in the ratio panel for each training variable (ymax_code.keys()=feature_labels)
    delta_OBS:       (float) value of the delta term after training (if not given, only tau reconstruction is plotted)
    output_delta_ref:(numpy array, shape (None, 1)) delta prediction of the reference training sample after training (if not given, only tau reconstruction is plotted)
    '''
    # used to regularize empty reference bins
    eps = 1e-10 

    weight_ref = np.ones(len(ref))*weight_ref
    weight_data = np.ones(len(data))*weight_data

    # Dimention
    dim = data.shape[-1]
    
    Zscore=norm.ppf(chi2.cdf(t_obs, df))

    for i in range(dim):

      bins = np.linspace(0,1.5,24)
      plt.rcParams["font.family"] = "serif"
      plt.style.use('classic')
      fig = plt.figure(figsize=(8, 8)) 
      fig.patch.set_facecolor('white')  
      ax1= fig.add_axes([0.1, 0.43, 0.8, 0.5])        
      hD = plt.hist(data[:, i],weights=weight_data, bins=bins, label='DATA', color='black', lw=1.5, histtype='step', zorder=2)
      hR = plt.hist(ref[:, i], weights=weight_ref, color='#a6cee3', ec='#1f78b4', bins=bins, lw=1, label='REFERENCE', zorder=1)
      hN = plt.hist(ref[:, i], weights=np.exp(ref_preds[:, 0])*weight_ref, histtype='step', bins=bins, lw=0)
    
      plt.errorbar(0.5*(bins[1:]+bins[:-1]), hD[0], yerr= np.sqrt(hD[0]), color='black', ls='', marker='o', ms=5, zorder=3)
      plt.scatter(0.5*(bins[1:]+bins[:-1]),  hN[0], edgecolor='black', label='RECO', color='#b2df8a', lw=1, s=30, zorder=4)

      font = font_manager.FontProperties(family='serif', size=16)
      l    = plt.legend(fontsize=18, prop=font, ncol=2)
      font = font_manager.FontProperties(family='serif', size=18) 
      title  = 't='+str(np.around(t_obs, 2))
      
      title += ', Z-score='+str(np.around(Zscore, 2))
      l.set_title(title=title, prop=font)
      plt.tick_params(axis='x', which='both',    labelbottom=False)
      plt.yticks(fontsize=16, fontname='serif')
      plt.xlim(0, 1.5)
      plt.ylabel("events", fontsize=22, fontname='serif')
      plt.yscale('log')
      ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.3]) 
      x   = 0.5*(bins[1:]+bins[:-1])
      plt.errorbar(x, hD[0]/(hR[0]+eps), yerr=np.sqrt(hD[0])/(hR[0]+eps), ls='', marker='o', label ='DATA/REF', color='black')
      plt.plot(x, hN[0]/(hR[0]+eps), label ='RECO', color='#b2df8a', lw=3)

      font = font_manager.FontProperties(family='serif', size=16)
      plt.legend(fontsize=18, prop=font)
      plt.xlabel('x', fontsize=22, fontname='serif')
      plt.ylabel("ratio", fontsize=22, fontname='serif')

      plt.yticks(fontsize=16, fontname='serif')
      plt.xticks(fontsize=16, fontname='serif')
      plt.xlim(bins[0], bins[-1])
      plt.ylim(0,10)
      plt.grid()
      if save:
          os.makedirs(save_path, exist_ok=True)
          fig.savefig(save_path + 'dim'+ '-'+ '{}'.format(i+1)+ file_name)
      plt.show()
      plt.close()

    return

# %%
# for 2-D with plot-reconstruction (with passing data)

def run_toys(sig, data, fraud, genuine, output_path, N_0, N0, NS, flk_config, toys=np.arange(100), plots_freq=0, df=10, savefig=True):

    '''
    type of signal: "NP0", "NP1", "NP2", "NP3"
    output_path: directory (inside ./runs/) where to save results
    N_0: size of ref sample
    N0: expected num of bkg events
    NS: expected num of signal events
    flk_config: dictionary of logfalkon parameters
    toys: numpy array with seeds for toy generation
    plots_freq: how often to plot inputs with learned reconstructions
    df: degree of freedom of chi^2 for plots
    '''

    output_path = "./runs/" + output_path
    os.makedirs(output_path, exist_ok=True)

    #save config file (temporary solution)
    with open(output_path+"/flk_config.txt","w") as f:
        f.write( str(flk_config) )

    weight = N0/N_0
    # passing data
    samples = data

    
    # dividing the dataset
    fraud_df = fraud
    non_fraud_df = genuine

    dim = 2

    for i in toys:

        st_time = time.time()

        rng = np.random.default_rng(i)

        # Shuffling the data
        samples = samples.sample(frac=1, random_state=i)
        fraud_df = fraud_df.sample(frac=1,random_state=i)
        non_fraud_df = non_fraud_df.sample(frac=1,random_state=i)

        N0p = rng.poisson(lam=N0)
        if sig!="NP0": NSp = rng.poisson(lam=NS) # if data contains anomalies
        else: NSp = 0

        N = N_0 + N0p + NSp

        print("[--] Toy {}: ".format(i))
        # build training set
        # initialize dataset
        # fill with ref, bkg and data
        if sig=="NP0":
            X = non_fraud_df[['V11','V14']].sample(n= N, replace=False, random_state=i) # both reference and data contain only bkg events (no NP component)
        else:
            X = np.zeros(shape=(N,dim))
            X[:N_0+N0p,:] = non_fraud_df[['V11','V14']].sample(n= N_0+N0p, replace=False, random_state=i) # ref and bkg
            X[N_0+N0p:,:] = fraud_df[['V11','V14']].sample(n= NSp, replace=False, random_state=i) # signal
        # initialize labes
        Y = np.zeros(shape=(N,1))
        Y[N_0:,:] = np.ones((N0p+NSp,1)) # flip data labels to one
        X = np.array(X)
        
        print("[--] Reference shape:{}".format(X[Y.flatten()==0].shape))
        print("[--] Data shape:{}".format(X[Y.flatten()==1].shape))

        # in this 1D case, there is no need to standardize
        #Xoriginal = X.copy()
        #X = standardize(X)

        # learn_t
        flk_config['seed']=i # select different centers for different toys

        preds = trainer(X,Y,flk_config)

        t = compute_t(preds,Y,weight)

        dt = round(time.time()-st_time,2)

        print("t = {}\nTime = {} sec\n\t".format(t,dt))

        with open(output_path+"t.txt", 'a') as f:
            f.write('{},{}\n'.format(i,t))
        
        if plots_freq!=0 and t>0 and i in toys[::plots_freq]:
            plot_reconstruction(data=X[Y.flatten()==1], weight_data=1, ref=X[Y.flatten()==0], weight_ref=weight, df=df, t_obs=t, ref_preds=preds[Y.flatten()==0],
                        save=savefig, save_path=output_path+'/plots/', file_name='sig_'+sig+'_NS{}_seed{}.pdf'.format(NS,i)
                    )

# %%
def get_results(ref, data, dof=None):
  md_tref = round(np.median(ref), 2)
  md_tdata = round(np.median(data), 2)
  max_zemp = emp_zscore(ref,np.max(ref))
  zemp = emp_zscore(ref,np.median(data))
  if dof:
      z_chi2 = round(chi2_zscore(np.median(data),dof=dof),2)

  return {"md_tref":md_tref,
          "md_tdata":md_tdata,
          "max_zemp":max_zemp,
          "zemp":zemp,
          "dof":dof,
          "z_chi2":z_chi2}

# %%
import itertools

def GridSearch(parms):

  res = []

  # Loading the dataset
  creds = pd.read_csv("drive/MyDrive/SimulatedDataset/creditcard.csv")
  fraud_samples = creds.loc[creds['Class'] == 1]
  genuine_samples = creds.loc[creds['Class'] == 0]

  combinations = itertools.product(*(parms[Name] for Name in parms.keys()))
  for row in list(combinations):

    # M should be less than N_0 and N0
    if row[2]<row[0] and row[2]<row[1]:
      # parameters
      flk_sigma = 3
      lam = 1e-7
      N_0, N0, M, NS = row[0], row[1], row[2], row[3]
      weight = N0/N_0

      flk_config = get_logflk_config(M,flk_sigma,[lam],weight=weight,iter=[100],seed=None,cpu=True)

      # Running the codes on reference dataset 
      NS_temp = 0
      run_toys("NP0", creds, fraud_samples, genuine_samples, "./reference/", N_0, N0, NS_temp, flk_config, toys=np.arange(100), df= 22)

      # Best DoF
      best = return_best_chi2dof(np.loadtxt('/content/runs/reference/t.txt',delimiter=',')[:,1])

      # Running the codes on all data
      run_toys("NP1", creds, fraud_samples, genuine_samples, "./NP1/", N_0, N0, NS, flk_config, toys=np.arange(100), df= best[0])

      # Collecting the important results for comparison
      results = get_results(np.loadtxt('/content/runs/reference/t.txt',delimiter=',')[:,1],np.loadtxt('/content/runs/NP1/t.txt',delimiter=',')[:,1],dof=best[0])

      # adding the parameters info to the collected data for comparison
      results.update({"N_0": N_0, "N0": N0, "M": M, "NS": NS})
      # Updating the whole Results
      res.append(results)

  return res

# %%
N_0 = 3000 # size of reference sample
N0 = 1000 # expected background
weight = N0/N_0

M = 800
lam = 1e-10
flk_sigma = 3
creds = pd.read_csv("drive/MyDrive/CreditCards/creditcard.csv")
fraud_samples = creds.loc[creds['Class'] == 1]
genuine_samples = creds.loc[creds['Class'] == 0]

flk_config = get_logflk_config(M,flk_sigma,[lam],weight=weight,iter=[100],seed=None,cpu=True) # seed is set inside learn_t function

# null hypothesis
NS = 0 # expected NP component
run_toys("NP0", creds, fraud_samples, genuine_samples, "./reference/", N_0, N0, NS, flk_config, toys=np.arange(300), plots_freq= 20, df= 22)
# Out:
# [--] Toy 0:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1012, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 44.777118926634756
# Time = 4.85 sec
# [--] Toy 1:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1001, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 43.47134314159976
# Time = 7.06 sec
#
# [--] Toy 2:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(977, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 67.8113058277185
# Time = 2.72 sec
#
# [--] Toy 3:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(948, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 61.36665720547085
# Time = 4.1 sec
#
# [--] Toy 4:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1066, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 59.019750205521376
# Time = 2.31 sec
#
# [--] Toy 5:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1031, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 63.19847180459837
# Time = 4.29 sec
#
# [--] Toy 6:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1003, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 61.6861355163394
# Time = 4.52 sec
#
# [--] Toy 7:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1011, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 60.34185088614447
# Time = 4.99 sec
#
# [--] Toy 8:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(983, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 100.89293089513458
# Time = 3.83 sec
#
# [--] Toy 9:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1041, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 65.18339039765083
# Time = 5.4 sec
#
# [--] Toy 10:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1077, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 75.6963759884172
# Time = 4.46 sec
#
# [--] Toy 11:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(959, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.28984865933752
# Time = 4.63 sec
#
# [--] Toy 12:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(968, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 68.06929854600827
# Time = 4.96 sec
#
# [--] Toy 13:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1040, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 83.43695527453183
# Time = 6.23 sec
#
# [--] Toy 14:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1034, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 61.90182155981416
# Time = 4.23 sec
#
# [--] Toy 15:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(
 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 61.77410550331362
# Time = 3.73 sec
#
# [--] Toy 218:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1030, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 84.8942877461966
# Time = 4.28 sec
#
# [--] Toy 219:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1018, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 69.46429154804264
# Time = 5.12 sec
#
# [--] Toy 220:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1045, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 58.11153294850813
# Time = 4.36 sec
# [--] Toy 221:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(996, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 58.10589298263128
# Time = 4.17 sec
#
# [--] Toy 222:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(989, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 63.74991680630145
# Time = 3.39 sec
#
# [--] Toy 223:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1045, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 50.53396346013437
# Time = 4.98 sec
#
# [--] Toy 224:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1004, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 74.57472277982312
# Time = 5.21 sec
#
# [--] Toy 225:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1009, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 76.85474572898725
# Time = 4.17 sec
#
# [--] Toy 226:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1016, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 73.53598706191394
# Time = 4.01 sec
#
# [--] Toy 227:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1000, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 54.832581822582874
# Time = 5.72 sec
#
# [--] Toy 228:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1015, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 81.46422627927227
# Time = 9.6 sec
#
# [--] Toy 229:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1043, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 69.77183221281152
# Time = 4.29 sec
#
# [--] Toy 230:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(991, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 60.58850462873461
# Time = 5.49 sec
#
# [--] Toy 231:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1004, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.51415902956116
# Time = 4.5 sec
#
# [--] Toy 232:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1007, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 64.30020709178142
# Time = 4.74 sec
#
# [--] Toy 233:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(950, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.66168413510479
# Time = 5.35 sec
#
# [--] Toy 234:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1030, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 63.81671260877586
# Time = 5.45 sec
#
# [--] Toy 235:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1000, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 57.84213999559966
# Time = 4.49 sec
#
# [--] Toy 236:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1034, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 50.76605044850146
# Time = 4.15 sec
#
# [--] Toy 237:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(998, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 56.375733935744606
# Time = 5.31 sec
#
# [--] Toy 238:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(992, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 57.25311185908785
# Time = 4.61 sec
#
# [--] Toy 239:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1020, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 60.82593847268353
# Time = 4.58 sec
#
# [--] Toy 240:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1015, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 64.46630676124607
# Time = 3.07 sec
# [--] Toy 241:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(972, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 65.68202225965503
# Time = 4.26 sec
#
# [--] Toy 242:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(948, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 76.81351569110726
# Time = 2.74 sec
#
# [--] Toy 243:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(997, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 65.55400142610293
# Time = 3.88 sec
#
# [--] Toy 244:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(950, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 77.34899054703111
# Time = 5.22 sec
#
# [--] Toy 245:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(992, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 50.43032070274241
# Time = 6.14 sec
#
# [--] Toy 246:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(976, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 47.12603739956717
# Time = 3.82 sec
#
# [--] Toy 247:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1025, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 88.3918496546793
# Time = 6.71 sec
#
# [--] Toy 248:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1014, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 60.6927872949211
# Time = 4.35 sec
#
# [--] Toy 249:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1062, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.47960969880909
# Time = 8.73 sec
#
# [--] Toy 250:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(970, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 51.879293773538336
# Time = 5.26 sec
#
# [--] Toy 251:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1005, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 67.59558158608414
# Time = 5.27 sec
#
# [--] Toy 252:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1006, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 62.649645049227026
# Time = 4.29 sec
#
# [--] Toy 253:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(976, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 59.39952785118833
# Time = 4.28 sec
#
# [--] Toy 254:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(995, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 80.87645877904961
# Time = 6.55 sec
#
# [--] Toy 255:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1031, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 78.87245235984904
# Time = 4.88 sec
#
# [--] Toy 256:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(962, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 82.69368666864695
# Time = 4.5 sec
#
# [--] Toy 257:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1024, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 54.21916940441206
# Time = 3.25 sec
#
# [--] Toy 258:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(986, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 63.51096873601145
# Time = 3.59 sec
#
# [--] Toy 259:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1009, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 68.27728686270609
# Time = 5.3 sec
#
# [--] Toy 260:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1059, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 84.47107911377034
# Time = 4.07 sec
# [--] Toy 261:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(985, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 50.545928201065536
# Time = 2.5 sec
#
# [--] Toy 262:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1036, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 70.24236263891692
# Time = 4.35 sec
#
# [--] Toy 263:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(985, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 63.057297761003944
# Time = 3.18 sec
#
# [--] Toy 264:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(989, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 94.13837654175228
# Time = 5.88 sec
#
# [--] Toy 265:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(983, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 60.292052880998455
# Time = 5.99 sec
#
# [--] Toy 266:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(970, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 60.58598215703906
# Time = 3.01 sec
#
# [--] Toy 267:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1007, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 52.52931603966467
# Time = 4.83 sec
#
# [--] Toy 268:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1052, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 56.18249433933396
# Time = 5.69 sec
#
# [--] Toy 269:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(982, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 55.0607199493063
# Time = 3.7 sec
#
# [--] Toy 270:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(990, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 62.19124108506079
# Time = 5.18 sec
#
# [--] Toy 271:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1028, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 96.83687258598869
# Time = 5.78 sec
#
# [--] Toy 272:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(994, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.97405497179356
# Time = 5.35 sec
#
# [--] Toy 273:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(969, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 63.00191622572963
# Time = 3.5 sec
#
# [--] Toy 274:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(997, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.67459506535754
# Time = 5.4 sec
#
# [--] Toy 275:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1056, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 79.54062249883053
# Time = 6.46 sec
#
# [--] Toy 276:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1033, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 77.08378905930954
# Time = 7.08 sec
#
# [--] Toy 277:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1001, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 44.96788737985568
# Time = 2.73 sec
#
# [--] Toy 278:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1019, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 89.39635291202313
# Time = 4.74 sec
#
# [--] Toy 279:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(952, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 70.18820065172787
# Time = 4.12 sec
#
# [--] Toy 280:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1026, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 66.32285286940268
# Time = 7.66 sec
# [--] Toy 281:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(995, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 68.02585822785022
# Time = 4.03 sec
#
# [--] Toy 282:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1011, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 52.56510817338777
# Time = 5.07 sec
#
# [--] Toy 283:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1024, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 59.344534319545396
# Time = 5.25 sec
#
# [--] Toy 284:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1012, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 64.21782961042959
# Time = 5.15 sec
#
# [--] Toy 285:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(920, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 54.77472211596435
# Time = 6.95 sec
#
# [--] Toy 286:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(993, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 49.20246362844634
# Time = 3.79 sec
#
# [--] Toy 287:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1038, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 70.65562556677939
# Time = 7.39 sec
#
# [--] Toy 288:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1022, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 83.82647502656043
# Time = 4.55 sec
#
# [--] Toy 289:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1036, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.0601849492261
# Time = 5.1 sec
#
# [--] Toy 290:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(990, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 62.480618883520776
# Time = 2.73 sec
#
# [--] Toy 291:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(969, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 64.36308945888311
# Time = 4.39 sec
#
# [--] Toy 292:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1022, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 58.49552689892939
# Time = 4.06 sec
#
# [--] Toy 293:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1018, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 51.86183672359883
# Time = 4.11 sec
#
# [--] Toy 294:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1013, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 74.67987293996855
# Time = 5.21 sec
#
# [--] Toy 295:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(961, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 60.61409829142323
# Time = 5.79 sec
#
# [--] Toy 296:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1015, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 67.3903664944267
# Time = 7.67 sec
#
# [--] Toy 297:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(943, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 70.03358317844157
# Time = 2.13 sec
#
# [--] Toy 298:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1001, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 83.47182165404362
# Time = 4.94 sec
#
# [--] Toy 299:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1020, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 95.01138185944654
# Time = 7.12 sec

# %%
best = return_best_chi2dof(np.loadtxt('/content/runs/reference/t.txt',delimiter=',')[:,1])
best
# Out:
# (65.84612070040515, 0.03887158933972481)

# %%
N_0 = 3000 # size of reference sample
N0 = 1000 # expected background
weight = N0/N_0

M = 800
lam = 1e-10
flk_sigma = 3
creds = pd.read_csv("drive/MyDrive/CreditCards/creditcard.csv")
fraud_samples = creds.loc[creds['Class'] == 1]
genuine_samples = creds.loc[creds['Class'] == 0]

flk_config = get_logflk_config(M,flk_sigma,[lam],weight=weight,iter=[100],seed=None,cpu=True) # seed is set inside learn_t function

# null hypothesis
NS = 10 # expected NP component
run_toys("NP1", creds, fraud_samples, genuine_samples, "./NP1/", N_0, N0, NS, flk_config, toys=np.arange(100), plots_freq= 20, df= best[0])
# Out:
# [--] Toy 0:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1014, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 52.43641830828419
# Time = 7.32 sec
# [--] Toy 1:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1009, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 62.50510891763675
# Time = 6.96 sec
#
# [--] Toy 2:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(990, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 89.96567689789177
# Time = 4.79 sec
#
# [--] Toy 3:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(961, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 91.68723430173512
# Time = 6.3 sec
#
# [--] Toy 4:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1087, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 109.23079859588233
# Time = 5.28 sec
#
# [--] Toy 5:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1041, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 75.34091004056243
# Time = 6.59 sec
#
# [--] Toy 6:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1012, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 81.02111751064555
# Time = 7.28 sec
#
# [--] Toy 7:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1024, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 87.61666982256827
# Time = 7.12 sec
#
# [--] Toy 8:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(997, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 141.20559874979574
# Time = 9.47 sec
#
# [--] Toy 9:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1052, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 101.7127174493397
# Time = 6.38 sec
#
# [--] Toy 10:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1090, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 111.00588297989418
# Time = 5.95 sec
#
# [--] Toy 11:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(970, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 95.13817742021675
# Time = 5.72 sec
#
# [--] Toy 12:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(976, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 76.59748850064935
# Time = 6.86 sec
#
# [--] Toy 13:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1053, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 125.39391185902053
# Time = 10.99 sec
#
# [--] Toy 14:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1045, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 88.41686663627175
# Time = 6.76 sec
#
# [--] Toy 15:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1026, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 79.94753653279032
# Time = 7.7 sec
#
# [--] Toy 16:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1011, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 65.36219216992733
# Time = 3.73 sec
#
# [--] Toy 17:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1047, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 108.95032187170412
# Time = 8.1 sec
#
# [--] Toy 18:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(999, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 74.5765409674862
# Time = 8.02 sec
#
# [--] Toy 19:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1001, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 88.5463033979554
# Time = 5.9 sec
#
# [--] Toy 20:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(985, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 75.65204309828403
# Time = 6.49 sec
# [--] Toy 21:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1040, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 96.18607822156616
# Time = 6.87 sec
#
# [--] Toy 22:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(993, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 61.69711244067367
# Time = 5.49 sec
#
# [--] Toy 23:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1024, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 93.59178598161103
# Time = 6.84 sec
#
# [--] Toy 24:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(995, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 94.52672638380035
# Time = 8.82 sec
#
# [--] Toy 25:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(971, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 106.89337041283252
# Time = 9.28 sec
#
# [--] Toy 26:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1012, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 96.63832297830365
# Time = 7.81 sec
#
# [--] Toy 27:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1024, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 75.28985086047257
# Time = 6.07 sec
#
# [--] Toy 28:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1051, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 93.52205753807947
# Time = 8.82 sec
#
# [--] Toy 29:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(938, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 105.36367793721524
# Time = 5.35 sec
#
# [--] Toy 30:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(979, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 72.39830891371665
# Time = 5.49 sec
#
# [--] Toy 31:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1061, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 65.66073409424365
# Time = 8.63 sec
#
# [--] Toy 32:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(973, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 70.34922649081872
# Time = 4.72 sec
#
# [--] Toy 33:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1010, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 86.59457495144233
# Time = 9.24 sec
#
# [--] Toy 34:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(985, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 74.71344819484028
# Time = 6.66 sec
#
# [--] Toy 35:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(990, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 67.41867994456666
# Time = 4.63 sec
#
# [--] Toy 36:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(982, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 94.6373264788375
# Time = 6.96 sec
#
# [--] Toy 37:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1027, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 85.27914047668017
# Time = 5.08 sec
#
# [--] Toy 38:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1011, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 106.49609468986216
# Time = 7.27 sec
#
# [--] Toy 39:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1006, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 67.93514505180025
# Time = 7.38 sec
#
# [--] Toy 40:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1038, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 95.80932360611023
# Time = 8.54 sec
# [--] Toy 41:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(972, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 95.93955958340831
# Time = 6.25 sec
#
# [--] Toy 42:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1033, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 85.87932642765901
# Time = 7.17 sec
#
# [--] Toy 43:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1025, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 70.05327043114806
# Time = 8.22 sec
#
# [--] Toy 44:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(963, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 74.42990955305436
# Time = 9.25 sec
#
# [--] Toy 45:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1017, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 113.5297592203598
# Time = 7.38 sec
#
# [--] Toy 46:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1058, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 90.08356417358651
# Time = 8.01 sec
#
# [--] Toy 47:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1033, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 81.68585560902773
# Time = 5.25 sec
#
# [--] Toy 48:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1000, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 94.60661957823099
# Time = 7.11 sec
#
# [--] Toy 49:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(996, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 97.82886296250254
# Time = 7.72 sec
#
# [--] Toy 50:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1035, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 82.45275526126606
# Time = 4.89 sec
#
# [--] Toy 51:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1073, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 98.3644045163873
# Time = 8.18 sec
#
# [--] Toy 52:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1020, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 77.24126164519308
# Time = 5.34 sec
#
# [--] Toy 53:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(989, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 86.93613260461703
# Time = 8.29 sec
#
# [--] Toy 54:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(978, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 69.31020587396971
# Time = 7.56 sec
#
# [--] Toy 55:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1042, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 70.84155967889603
# Time = 6.06 sec
#
# [--] Toy 56:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1031, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 92.16586783401011
# Time = 6.86 sec
#
# [--] Toy 57:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1031, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 81.25802176250969
# Time = 7.89 sec
#
# [--] Toy 58:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(989, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 77.67944752874698
# Time = 8.2 sec
#
# [--] Toy 59:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1013, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 77.16143011633982
# Time = 4.35 sec
#
# [--] Toy 60:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(998, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 110.1135541053675
# Time = 7.01 sec
# [--] Toy 61:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1000, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 85.95391935753747
# Time = 6.26 sec
#
# [--] Toy 62:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1023, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 88.61258387074984
# Time = 8.32 sec
#
# [--] Toy 63:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1012, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 61.57112782445931
# Time = 8.62 sec
#
# [--] Toy 64:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1070, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 73.00790527435854
# Time = 6.8 sec
#
# [--] Toy 65:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(935, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 82.22739386123101
# Time = 6.02 sec
#
# [--] Toy 66:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1066, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 67.2115691551192
# Time = 7.85 sec
#
# [--] Toy 67:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1002, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 75.96398843111592
# Time = 8.29 sec
#
# [--] Toy 68:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1011, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 81.95327840980083
# Time = 5.73 sec
#
# [--] Toy 69:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1017, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 95.92196093322599
# Time = 8.16 sec
#
# [--] Toy 70:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1001, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 77.27999978426347
# Time = 8.15 sec
#
# [--] Toy 71:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(989, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 111.65995412572748
# Time = 7.55 sec
#
# [--] Toy 72:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1042, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 66.68573476648895
# Time = 7.07 sec
#
# [--] Toy 73:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1006, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 103.86974720840232
# Time = 8.95 sec
#
# [--] Toy 74:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1058, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 87.39490574617045
# Time = 9.4 sec
#
# [--] Toy 75:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(983, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 84.88630151572242
# Time = 9.3 sec
#
# [--] Toy 76:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1021, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 83.17749284788906
# Time = 7.85 sec
#
# [--] Toy 77:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1035, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 80.4657204552143
# Time = 5.53 sec
#
# [--] Toy 78:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1003, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 95.3385052059721
# Time = 7.82 sec
#
# [--] Toy 79:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1069, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 128.42060617156037
# Time = 7.74 sec
#
# [--] Toy 80:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1034, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 81.09828134694054
# Time = 5.42 sec
# [--] Toy 81:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1009, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 101.11225311860997
# Time = 9.53 sec
#
# [--] Toy 82:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(999, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 94.57799213225951
# Time = 8.94 sec
#
# [--] Toy 83:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(994, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 90.07989452736352
# Time = 6.77 sec
#
# [--] Toy 84:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1029, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 94.84817119209424
# Time = 5.83 sec
#
# [--] Toy 85:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(933, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 87.48284298263826
# Time = 8.73 sec
#
# [--] Toy 86:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1021, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 106.60138804813839
# Time = 9.35 sec
#
# [--] Toy 87:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1012, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 75.39625348081405
# Time = 6.84 sec
#
# [--] Toy 88:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(983, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 98.39361365839306
# Time = 7.4 sec
#
# [--] Toy 89:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1019, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 106.47469762216647
# Time = 7.39 sec
#
# [--] Toy 90:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(998, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 81.80854871155066
# Time = 7.74 sec
#
# [--] Toy 91:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(992, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 114.33288035868819
# Time = 7.88 sec
#
# [--] Toy 92:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1017, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 81.49600748287224
# Time = 5.72 sec
#
# [--] Toy 93:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1008, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 84.78604064261481
# Time = 7.92 sec
#
# [--] Toy 94:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(987, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 90.66784229008192
# Time = 5.5 sec
#
# [--] Toy 95:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1011, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.343126079449
# Time = 7.35 sec
#
# [--] Toy 96:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1032, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 86.28217788181811
# Time = 6.94 sec
#
# [--] Toy 97:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1017, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 56.89953146345745
# Time = 5.89 sec
#
# [--] Toy 98:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(947, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 57.0876048903542
# Time = 3.76 sec
#
# [--] Toy 99:
# [--] Reference shape:(3000, 2)
# [--] Data shape:(1011, 2)
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
# t = 71.22005010638466
# Time = 6.59 sec

# %%
# in utils.py you additional functions can be found to plot the test statistics
tobs = np.loadtxt('/content/runs/reference/t.txt',delimiter=',')[:,1]
tobs = [t for t in tobs if t >= 0]  # remove the negative element

plot_ref_data(ref=np.array(tobs), data=np.loadtxt('/content/runs/NP1/t.txt',delimiter=',')[:,1], dof=best[0],
              name='NP1', out_path='./fig', title='T distribution (Reference-vs-NP1)', density=True, bins=10,
              c_ref='#abd9e9', e_ref='#2c7bb6', c_sig='#fdae61', e_sig='#d7191c')

# %%
metrics_plots("drive/MyDrive/CreditCards/creditcard.csv", "./fig/", N_0, N0, NS, flk_config, df= best[0])
# Out:
# Iteration 0 - penalty 1.000000e-10 - sub-iterations 100
