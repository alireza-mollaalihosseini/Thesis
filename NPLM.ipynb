# %%
pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu113
# Collecting torch==1.11.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.11.0%2Bcu113-cp37-cp37m-linux_x86_64.whl (1637.0 MB)
#      |████████████████▎               | 834.1 MB 1.4 MB/s eta 0:09:52tcmalloc: large alloc 1147494400 bytes == 0x655e2000 @  0x7fbda633f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |████████████████████▋           | 1055.7 MB 1.5 MB/s eta 0:06:35tcmalloc: large alloc 1434370048 bytes == 0x2e0a000 @  0x7fbda633f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |██████████████████████████▏     | 1336.2 MB 1.4 MB/s eta 0:03:35tcmalloc: large alloc 1792966656 bytes == 0x585f6000 @  0x7fbda633f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |████████████████████████████████| 1636.9 MB 1.2 MB/s eta 0:00:01tcmalloc: large alloc 1636958208 bytes == 0xc33de000 @  0x7fbda633e1e7 0x4b2590 0x4b261c 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6
# tcmalloc: large alloc 2046197760 bytes == 0x124cfe000 @  0x7fbda633f615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x5b4ee6 0x58ff2e 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x4bad99 0x4d3249
#      |████████████████████████████████| 1637.0 MB 5.6 kB/s
# Collecting torchvision==0.12.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.12.0%2Bcu113-cp37-cp37m-linux_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.5 MB/s
# Collecting torchaudio==0.11.0
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.11.0%2Bcu113-cp37-cp37m-linux_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 36.1 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.11.0+cu113) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.12.0+cu113) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision==0.12.0+cu113) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.12.0+cu113) (1.21.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision==0.12.0+cu113) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision==0.12.0+cu113) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision==0.12.0+cu113) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision==0.12.0+cu113) (1.24.3)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1+cu113
#     Uninstalling torchaudio-0.12.1+cu113:
#       Successfully uninstalled torchaudio-0.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.11.0+cu113 which is incompatible.
# Successfully installed torch-1.11.0+cu113 torchaudio-0.11.0+cu113 torchvision-0.12.0+cu113

# %%
import scipy
import torch
import matplotlib.pyplot as plt

# %%
# To check Pytorch version
print(torch.__version__)
# Out:
# 1.11.0+cu113

# %%
# To check GPU availability
# assert torch.cuda.is_available()

# %%
# To install Falkon library
# !pip install git+https://github.com/falkonml/falkon.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/falkonml/falkon.git
#   Cloning https://github.com/falkonml/falkon.git to /tmp/pip-req-build-r1o6v91p
#   Running command git clone -q https://github.com/falkonml/falkon.git /tmp/pip-req-build-r1o6v91p
# Collecting keopscore@ git+https://github.com/getkeops/keops@ad044a671fdc3c2790b0321f6b9f9b5aa3d220df#subdirectory=keopscore
#   Cloning https://github.com/getkeops/keops (to revision ad044a671fdc3c2790b0321f6b9f9b5aa3d220df) to /tmp/pip-install-g_u5a_lm/keopscore_1feebbb5c9434d88a381746963e85e66
#   Running command git clone -q https://github.com/getkeops/keops /tmp/pip-install-g_u5a_lm/keopscore_1feebbb5c9434d88a381746963e85e66
#   Running command git rev-parse -q --verify 'sha^ad044a671fdc3c2790b0321f6b9f9b5aa3d220df'
#   Running command git fetch -q https://github.com/getkeops/keops ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Running command git checkout -q ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Running command git submodule update --init --recursive -q
# Collecting pykeops@ git+https://github.com/getkeops/keops@ad044a671fdc3c2790b0321f6b9f9b5aa3d220df#subdirectory=pykeops
#   Cloning https://github.com/getkeops/keops (to revision ad044a671fdc3c2790b0321f6b9f9b5aa3d220df) to /tmp/pip-install-g_u5a_lm/pykeops_41d8250928554c798c0f61ea5f1ebd61
#   Running command git clone -q https://github.com/getkeops/keops /tmp/pip-install-g_u5a_lm/pykeops_41d8250928554c798c0f61ea5f1ebd61
#   Running command git rev-parse -q --verify 'sha^ad044a671fdc3c2790b0321f6b9f9b5aa3d220df'
#   Running command git fetch -q https://github.com/getkeops/keops ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Running command git checkout -q ad044a671fdc3c2790b0321f6b9f9b5aa3d220df
#   Running command git submodule update --init --recursive -q
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.7/dist-packages (from falkon==0.7.5) (1.11.0+cu113)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from falkon==0.7.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from falkon==0.7.5) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from falkon==0.7.5) (1.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from falkon==0.7.5) (5.4.8)
# Collecting pybind11
#   Downloading pybind11-2.10.1-py3-none-any.whl (216 kB)
#      |████████████████████████████████| 216 kB 6.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.9->falkon==0.7.5) (4.1.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->falkon==0.7.5) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->falkon==0.7.5) (3.1.0)
# Building wheels for collected packages: falkon, keopscore, pykeops
#   Building wheel for falkon (setup.py) ... done
#   Created wheel for falkon: filename=falkon-0.7.5-cp37-cp37m-linux_x86_64.whl size=7472997 sha256=5fbcb6e9703363ea6356254c48503c8df4793e9439f3083ade14b9ab7999b272
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v9t6qps2/wheels/75/27/ad/00e6ab2927d21d32a305d81b49f2968c82800420d5ae1ec57d
#   Building wheel for keopscore (setup.py) ... done
#   Created wheel for keopscore: filename=keopscore-2.1-py3-none-any.whl size=147542 sha256=718b83e123a61f56ae5361302a987c5638b667979d5f6eef7760265318582a34
#   Stored in directory: /root/.cache/pip/wheels/5e/59/82/3d49b5a58309a9e99f9775f19573b3e3605ed4ee65b3977d67
#   Building wheel for pykeops (setup.py) ... done
#   Created wheel for pykeops: filename=pykeops-2.1-py3-none-any.whl size=112058 sha256=059a5390b20a460b247ebcca369046c6337b4b49509327b1561038dc7ca97811
#   Stored in directory: /root/.cache/pip/wheels/3d/65/76/7cc70d63a2f403271daf440cd506db2ffc8a51ef8f9531d9d2
# Successfully built falkon keopscore pykeops
# Installing collected packages: pybind11, keopscore, pykeops, falkon
# Successfully installed falkon-0.7.5 keopscore-2.1 pybind11-2.10.1 pykeops-2.1

# %%
import falkon
# Out:
# [KeOps] Warning : cuda was detected, but driver API could not be initialized. Switching to cpu only.

# %%
# Drive
from google.colab import drive

# we connect to the drive folder to work with the data stored
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp drive/MyDrive/NPLM/utils.py .

# %%
import numpy as np

from utils import get_logflk_config, run_toys, candidate_sigma, return_best_chi2dof, plot_ref_data

# %%
import utils

# %%
# to estimate flk_sigma from data use candidate_sigma on a reference sample 
tune_ref_sample = np.random.default_rng(0).exponential(scale=1/8, size=(10000,1))
candidate_sigma(tune_ref_sample)
# Out:
# 0.3

# %% [markdown]
# # Reference

# %%
N_0=200000 # size of reference sample
N0=2000 # expected background
weight=N0/N_0

M=3000
lam=1e-9
flk_sigma = 0.3

flk_config = get_logflk_config(M,flk_sigma,[lam],weight=weight,iter=[100],seed=None,cpu=True) # seed is set inside learn_t function

# null hypothesis
NS=0 # expected NP component
run_toys("NP0", "./reference/", N_0, N0, NS, flk_config, toys=np.arange(100), plots_freq=99, df=9.6)

# alternative hypothesis with NP1 signal
# NS=10 # expected NP component
# run_toys("NP3", "./NP3/", N_0, N0, NS, flk_config, toys=np.arange(100), plots_freq=20, df=9.6)
# Out:
# [--] Toy 0:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2018, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.418038317077219
# Time = 140.75 sec
# [--] Toy 1:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2001, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 11.734787975839442
# Time = 145.04 sec
#
# [--] Toy 2:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1968, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.641677091159707
# Time = 135.19 sec
#
# [--] Toy 3:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1926, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.341076251205862
# Time = 134.53 sec
#
# [--] Toy 4:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2094, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.408531954018372
# Time = 137.84 sec
#
# [--] Toy 5:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2043, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 2.92979630360621
# Time = 134.57 sec
#
# [--] Toy 6:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2005, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.970717948377239
# Time = 136.83 sec
#
# [--] Toy 7:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2016, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.243435874404877
# Time = 133.75 sec
#
# [--] Toy 8:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1976, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.596239476214272
# Time = 91.65 sec
#
# [--] Toy 9:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2058, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 25.816004644273974
# Time = 150.63 sec
#
# [--] Toy 10:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2109, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.644543473126816
# Time = 150.3 sec
#
# [--] Toy 11:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1942, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.154186479639336
# Time = 92.86 sec
#
# [--] Toy 12:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1955, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.597730222455425
# Time = 138.48 sec
#
# [--] Toy 13:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2057, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.360783449381373
# Time = 115.42 sec
#
# [--] Toy 14:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2049, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 13.461263447677766
# Time = 124.19 sec
#
# [--] Toy 15:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2025, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 13.302103125087761
# Time = 151.25 sec
#
# [--] Toy 16:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2008, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.55728019190116
# Time = 117.96 sec
#
# [--] Toy 17:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2052, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.92384945387532
# Time = 148.92 sec
#
# [--] Toy 18:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1987, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.817124503637874
# Time = 118.63 sec
#
# [--] Toy 19:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1990, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.185743264162074
# Time = 128.02 sec
#
# [--] Toy 20:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1970, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.058297931753764
# Time = 154.05 sec
#
# [--] Toy 21:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2039, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.322097776836529
# Time = 151.59 sec
#
# [--] Toy 22:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1983, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.39921841928102
# Time = 106.97 sec
#
# [--] Toy 23:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2026, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.4351444919207523
# Time = 146.55 sec
#
# [--] Toy 24:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1978, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.750840160922671
# Time = 142.04 sec
#
# [--] Toy 25:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1950, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.623460914897876
# Time = 152.27 sec
#
# [--] Toy 26:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1999, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.398236847018756
# Time = 107.2 sec
#
# [--] Toy 27:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2026, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.670005576838612
# Time = 130.19 sec
#
# [--] Toy 28:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2053, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.699211769322133
# Time = 147.89 sec
#
# [--] Toy 29:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1899, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.27559002877203
# Time = 119.3 sec
#
# [--] Toy 30:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1964, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 2.9382066491466503
# Time = 133.83 sec
#
# [--] Toy 31:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2069, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.969454092074983
# Time = 140.75 sec
#
# [--] Toy 32:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1949, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 13.204111768448627
# Time = 146.5 sec
#
# [--] Toy 33:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1993, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.991072461196373
# Time = 134.51 sec
#
# [--] Toy 34:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1965, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.407740970767563
# Time = 107.71 sec
#
# [--] Toy 35:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1979, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.836977539857365
# Time = 107.55 sec
#
# [--] Toy 36:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1954, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.947185551996114
# Time = 166.39 sec
#
# [--] Toy 37:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2027, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 4.367259222101865
# Time = 113.94 sec
#
# [--] Toy 38:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1998, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 4.884380482082084
# Time = 107.02 sec
#
# [--] Toy 39:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2000, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 4.648158660895404
# Time = 120.98 sec
#
# [--] Toy 40:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2031, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 4.174259577683635
# Time = 143.01 sec
#
# [--] Toy 41:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1941, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.410372557669021
# Time = 144.12 sec
#
# [--] Toy 42:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2038, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.103176745930412
# Time = 142.29 sec
#
# [--] Toy 43:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2020, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.213575741592592
# Time = 94.13 sec
#
# [--] Toy 44:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1940, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.682633569820908
# Time = 165.32 sec
#
# [--] Toy 45:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2009, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.308275480465683
# Time = 117.43 sec
#
# [--] Toy 46:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2070, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.375743284670506
# Time = 154.55 sec
#
# [--] Toy 47:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2033, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.829202756085209
# Time = 118.54 sec
#
# [--] Toy 48:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1986, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.308157599597308
# Time = 120.34 sec
#
# [--] Toy 49:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1982, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.910628914285262
# Time = 118.99 sec
#
# [--] Toy 50:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2040, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.640480733249007
# Time = 149.99 sec
#
# [--] Toy 51:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2093, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 15.950319999062089
# Time = 159.35 sec
#
# [--] Toy 52:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2015, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 2.923722913414686
# Time = 140.77 sec
#
# [--] Toy 53:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1978, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.934565375075287
# Time = 157.49 sec
#
# [--] Toy 54:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1961, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.316585166993633
# Time = 153.94 sec
#
# [--] Toy 55:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2049, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.446758878144152
# Time = 145.68 sec
#
# [--] Toy 56:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2030, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.489208409517744
# Time = 109.05 sec
#
# [--] Toy 57:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2024, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 1.7437014831402209
# Time = 125.96 sec
#
# [--] Toy 58:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1975, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.471036115336915
# Time = 147.63 sec
#
# [--] Toy 59:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2011, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.5296279023450765
# Time = 85.27 sec
#
# [--] Toy 60:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1977, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.6308666241511744
# Time = 124.07 sec
#
# [--] Toy 61:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1984, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 11.25044990068329
# Time = 156.6 sec
#
# [--] Toy 62:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2014, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 2.090099734142605
# Time = 119.07 sec
#
# [--] Toy 63:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1957, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 11.135727579489782
# Time = 156.19 sec
#
# [--] Toy 64:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2094, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.948893417397983
# Time = 148.08 sec
#
# [--] Toy 65:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1895, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.30513951630303
# Time = 126.03 sec
#
# [--] Toy 66:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2079, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.222800939223049
# Time = 119.37 sec
#
# [--] Toy 67:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1989, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.368953176300572
# Time = 154.26 sec
#
# [--] Toy 68:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1998, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.9977069025749508
# Time = 117.01 sec
#
# [--] Toy 69:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2010, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = -9.09077260785795
# Time = 159.36 sec
#
# [--] Toy 70:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1985, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.708314702501895
# Time = 137.89 sec
#
# [--] Toy 71:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1966, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.94305824049718
# Time = 145.5 sec
#
# [--] Toy 72:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2050, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.9210703036613666
# Time = 149.66 sec
#
# [--] Toy 73:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1999, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.8887835649207405
# Time = 119.55 sec
#
# [--] Toy 74:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2066, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 13.300694038187231
# Time = 150.88 sec
#
# [--] Toy 75:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1960, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.496963538766323
# Time = 145.02 sec
#
# [--] Toy 76:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2024, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.691992405445397
# Time = 151.62 sec
#
# [--] Toy 77:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2040, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.415911666392674
# Time = 117.93 sec
#
# [--] Toy 78:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1990, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.189924596368584
# Time = 122.75 sec
#
# [--] Toy 79:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2077, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.83705314218804
# Time = 152.87 sec
#
# [--] Toy 80:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2032, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.252447289805502
# Time = 139.9 sec
#
# [--] Toy 81:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1992, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.529222501745952
# Time = 140.51 sec
#
# [--] Toy 82:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1988, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 11.072215239477988
# Time = 161.54 sec
#
# [--] Toy 83:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1976, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 20.642598546215552
# Time = 117.4 sec
#
# [--] Toy 84:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2031, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.547284693450564
# Time = 139.25 sec
#
# [--] Toy 85:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1891, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 16.625291361323434
# Time = 122.88 sec
#
# [--] Toy 86:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2015, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 1.1114925939844404
# Time = 94.63 sec
#
# [--] Toy 87:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2009, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.686533266286386
# Time = 121.92 sec
#
# [--] Toy 88:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1959, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.7890305141600464
# Time = 163.25 sec
#
# [--] Toy 89:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2010, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.60381141942457
# Time = 139.25 sec
#
# [--] Toy 90:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1983, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.831105036363617
# Time = 116.92 sec
#
# [--] Toy 91:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1971, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 3.1744767562175724
# Time = 105.46 sec
#
# [--] Toy 92:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2013, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.985275814258312
# Time = 101.15 sec
#
# [--] Toy 93:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1995, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.396587928841912
# Time = 116.16 sec
#
# [--] Toy 94:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1964, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.319684254798588
# Time = 111.36 sec
#
# [--] Toy 95:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2005, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.352571368790747
# Time = 106.47 sec
#
# [--] Toy 96:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2031, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.906574253160123
# Time = 140.53 sec
#
# [--] Toy 97:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2023, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.23667184819741
# Time = 163.23 sec
#
# [--] Toy 98:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2094, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.284276812239682
# Time = 138.37 sec
#
# [--] Toy 99:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2001, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 5.1893336444911435
# Time = 117.55 sec

# %%
# to find the degree of freedom of the chi2 for the reference experiments, use the function return_best_chi2dof in utils.py

# in utils.py you additional functions can be found to plot the test statistics

# %% [markdown]
# # DoF calculation

# %%
tobs = np.loadtxt('t.txt',delimiter=',')[:,1]
tobs = [t for t in tobs if t >= 0]  # remove the negative element

# %%
from scipy.stats import norm, chi2, rv_continuous, kstest

dof_range = np.arange(np.nanmedian(tobs) - 10, np.nanmedian(tobs) + 10, 0.1)
dof_range = [df for df in dof_range if df>=0]  # remove the negative grids
    
ks_tests = []

for dof in dof_range:
        
    test = kstest(tobs, lambda x:chi2.cdf(x, df=dof))[0]

    ks_tests.append((dof, test))
        
best = min(ks_tests, key = lambda t: t[1]) # select best dof according to KS test result

# %%
best
# Out:
# (8.469454092074992, 0.043969282791062825)

# %% [markdown]
# # NP1

# %%
N_0=200000 # size of reference sample
N0=2000 # expected background
weight=N0/N_0

M=3000
lam=1e-9
flk_sigma = 0.3

flk_config = get_logflk_config(M,flk_sigma,[lam],weight=weight,iter=[100],seed=None,cpu=True) # seed is set inside learn_t function

# null hypothesis
# NS=0 # expected NP component
# run_toys("NP0", "./reference/", N_0, N0, NS, flk_config, toys=np.arange(100), plots_freq=99, df=9.6)

# alternative hypothesis with NP1 signal
NS=10 # expected NP component
run_toys("NP1", "./NP1/", N_0, N0, NS, flk_config, toys=np.arange(50), plots_freq=49, df= best[0])
# Out:
# [--] Toy 0:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2020, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.950977347424164
# Time = 134.64 sec
# [--] Toy 1:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2009, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 19.400269254575687
# Time = 158.43 sec
#
# [--] Toy 2:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1981, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 30.8081894882042
# Time = 136.2 sec
#
# [--] Toy 3:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1939, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 39.28757246837034
# Time = 171.81 sec
#
# [--] Toy 4:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2115, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 53.66346948449953
# Time = 194.54 sec
#
# [--] Toy 5:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2053, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.196821914210005
# Time = 168.8 sec
#
# [--] Toy 6:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2014, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.287648244644434
# Time = 178.78 sec
#
# [--] Toy 7:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2029, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 33.51111588782678
# Time = 192.4 sec
#
# [--] Toy 8:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1990, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 24.91372842628949
# Time = 180.81 sec
#
# [--] Toy 9:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2069, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 46.337315683512486
# Time = 180.0 sec
#
# [--] Toy 10:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2122, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 39.07638796243765
# Time = 187.66 sec
#
# [--] Toy 11:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1953, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 27.250270204477744
# Time = 165.66 sec
#
# [--] Toy 12:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1963, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 17.055807542867697
# Time = 163.9 sec
#
# [--] Toy 13:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2070, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 26.990987046581836
# Time = 137.34 sec
#
# [--] Toy 14:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2060, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 21.503783354284877
# Time = 163.83 sec
#
# [--] Toy 15:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2033, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 22.27048864741039
# Time = 125.55 sec
#
# [--] Toy 16:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2013, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 4.15411503219746
# Time = 160.9 sec
#
# [--] Toy 17:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2062, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.290954674790825
# Time = 141.23 sec
#
# [--] Toy 18:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1995, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 11.655071636367618
# Time = 186.86 sec
#
# [--] Toy 19:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1998, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.224875300184193
# Time = 117.46 sec
#
# [--] Toy 20:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1976, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 13.841068856458186
# Time = 152.93 sec
#
# [--] Toy 21:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2051, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 19.357378920946488
# Time = 175.1 sec
#
# [--] Toy 22:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1988, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.101910364262736
# Time = 139.48 sec
#
# [--] Toy 23:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2032, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.6760574072899175
# Time = 164.34 sec
#
# [--] Toy 24:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1989, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 31.117889007466157
# Time = 160.31 sec
#
# [--] Toy 25:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1957, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.62949957244227
# Time = 176.05 sec
#
# [--] Toy 26:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2012, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 30.80852862725546
# Time = 172.57 sec
#
# [--] Toy 27:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2032, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.731997184407938
# Time = 153.84 sec
#
# [--] Toy 28:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2066, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.3467323148582
# Time = 172.54 sec
#
# [--] Toy 29:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1909, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 33.34299274738808
# Time = 158.73 sec
#
# [--] Toy 30:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1969, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.6521497968986765
# Time = 146.78 sec
#
# [--] Toy 31:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2081, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 30.144178716561697
# Time = 185.37 sec
#
# [--] Toy 32:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1958, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 17.174290309346546
# Time = 170.49 sec
#
# [--] Toy 33:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2008, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 45.683619323784654
# Time = 101.16 sec
#
# [--] Toy 34:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1975, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 16.821616948045722
# Time = 129.63 sec
#
# [--] Toy 35:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1984, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 4.843901533665022
# Time = 141.79 sec
#
# [--] Toy 36:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1969, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 36.800857415793416
# Time = 155.31 sec
#
# [--] Toy 37:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2035, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 11.512134486653267
# Time = 126.72 sec
#
# [--] Toy 38:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2010, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 25.650097919380833
# Time = 142.25 sec
#
# [--] Toy 39:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2006, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 6.975795497965146
# Time = 158.94 sec
#
# [--] Toy 40:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2047, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 34.1160817544599
# Time = 137.35 sec
#
# [--] Toy 41:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1955, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 25.694836499312586
# Time = 156.89 sec
#
# [--] Toy 42:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2044, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.550672563991597
# Time = 161.83 sec
#
# [--] Toy 43:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2031, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 17.70553380423391
# Time = 130.27 sec
#
# [--] Toy 44:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1946, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 4.902784551158746
# Time = 180.71 sec
#
# [--] Toy 45:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2019, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 20.378166470005837
# Time = 181.19 sec
#
# [--] Toy 46:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2078, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 30.219884546736125
# Time = 163.68 sec
#
# [--] Toy 47:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2043, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 15.732687918826542
# Time = 160.41 sec
#
# [--] Toy 48:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1996, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 17.534257778620077
# Time = 160.57 sec
#
# [--] Toy 49:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1991, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.284488646277058
# Time = 153.94 sec

# %%
# in utils.py you additional functions can be found to plot the test statistics

plot_ref_data(ref=np.loadtxt('/content/t.txt',delimiter=',')[:,1], data=np.loadtxt('/content/runs/NP1/t.txt',delimiter=',')[:,1],
              name='NP1', out_path='./fig', title='T distribution (Reference-vs-NP1)', density=True, bins=10,
              c_ref='#abd9e9', e_ref='#2c7bb6', c_sig='#fdae61', e_sig='#d7191c')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-4087244adadb> in <module>
#       3 plot_ref_data(ref=np.loadtxt('/content/t.txt',delimiter=',')[:,1], data=np.loadtxt('/content/runs/NP1/t.txt',delimiter=',')[:,1],
#       4               name='NP1', out_path='./fig/', title='T distribution (Reference-vs-NP1)', density=True, bins=10,
# ----> 5               c_ref='#abd9e9', e_ref='#2c7bb6', c_sig='#fdae61', e_sig='#d7191c')
#
# /content/utils.py in plot_ref_data(ref, data, name, dof, out_path, title, density, bins, c_ref, e_ref, c_sig, e_sig)
#     518
#     519     if out_path:
# --> 520         plt.savefig(out_path+"/refdata_{}.pdf".format(name), bbox_inches='tight')
#     521
#     522     plt.close()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata, **kwargs)
#    2539             file = filename._file
#    2540         else:
# -> 2541             file = PdfFile(filename, metadata=metadata)
#    2542         try:
#    2543             file.newPage(width, height)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     457         self.original_file_like = None
#     458         self.tell_base = 0
# --> 459         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     460         if not opened:
#     461             try:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './fig//refdata_NP1.pdf'

# %% [markdown]
# # NP2

# %%
N_0=200000 # size of reference sample
N0=2000 # expected background
weight=N0/N_0

M=3000
lam=1e-9
flk_sigma = 0.3

flk_config = get_logflk_config(M,flk_sigma,[lam],weight=weight,iter=[100],seed=None,cpu=True) # seed is set inside learn_t function

# null hypothesis
# NS=0 # expected NP component
# run_toys("NP0", "./reference/", N_0, N0, NS, flk_config, toys=np.arange(100), plots_freq=99, df=9.6)

# alternative hypothesis with NP2 signal
NS=90 # expected NP component
run_toys("NP2", "./NP2/", N_0, N0, NS, flk_config, toys=np.arange(50), plots_freq=49, df= best[0])
# Out:
# [--] Toy 0:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2084, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 21.539636474904057
# Time = 160.44 sec
# [--] Toy 1:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2086, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 24.01330933774375
# Time = 149.34 sec
#
# [--] Toy 2:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2068, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 19.28013228523895
# Time = 132.14 sec
#
# [--] Toy 3:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2025, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 22.418158273608967
# Time = 157.61 sec
#
# [--] Toy 4:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2218, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 59.041874759202756
# Time = 125.25 sec
#
# [--] Toy 5:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2133, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 31.036843609023947
# Time = 129.93 sec
#
# [--] Toy 6:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2091, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 24.899992967811613
# Time = 178.71 sec
#
# [--] Toy 7:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2114, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 36.02514102012802
# Time = 160.26 sec
#
# [--] Toy 8:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2078, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 28.24977002057625
# Time = 160.98 sec
#
# [--] Toy 9:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2151, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 46.629070172962145
# Time = 163.8 sec
#
# [--] Toy 10:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2209, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 50.132221306385986
# Time = 158.95 sec
#
# [--] Toy 11:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2035, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 21.901941459455998
# Time = 153.55 sec
#
# [--] Toy 12:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2041, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 29.961183145094353
# Time = 133.53 sec
#
# [--] Toy 13:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2157, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 25.099275779235995
# Time = 160.16 sec
#
# [--] Toy 14:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2145, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 46.053623186615425
# Time = 164.01 sec
#
# [--] Toy 15:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2111, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 32.86881700708173
# Time = 167.69 sec
#
# [--] Toy 16:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2083, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 13.264872984960192
# Time = 155.29 sec
#
# [--] Toy 17:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2144, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 35.01177425518085
# Time = 149.66 sec
#
# [--] Toy 18:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2071, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 22.029994971618294
# Time = 181.34 sec
#
# [--] Toy 19:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2073, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 23.79611079108949
# Time = 133.59 sec
#
# [--] Toy 20:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2047, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.167274662780812
# Time = 165.11 sec
#
# [--] Toy 21:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2135, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 32.87520515383699
# Time = 145.34 sec
#
# [--] Toy 22:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2057, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 7.943239283239251
# Time = 126.19 sec
#
# [--] Toy 23:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2103, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 16.54910835723834
# Time = 168.74 sec
#
# [--] Toy 24:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2070, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 41.952180502739026
# Time = 164.63 sec
#
# [--] Toy 25:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2031, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.905709340693456
# Time = 169.09 sec
#
# [--] Toy 26:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2071, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 37.52540211435084
# Time = 132.97 sec
#
# [--] Toy 27:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2103, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 23.6576656676973
# Time = 140.75 sec
#
# [--] Toy 28:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2151, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 50.24985838503517
# Time = 168.33 sec
#
# [--] Toy 29:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1989, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.22407776846221
# Time = 128.23 sec
#
# [--] Toy 30:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2039, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.216649361586903
# Time = 161.45 sec
#
# [--] Toy 31:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2164, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 34.97862184505243
# Time = 121.4 sec
#
# [--] Toy 32:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2036, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.32916022674982
# Time = 114.0 sec
#
# [--] Toy 33:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2098, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 41.36061356442991
# Time = 160.77 sec
#
# [--] Toy 34:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2054, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 29.1877086214986
# Time = 167.62 sec
#
# [--] Toy 35:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2087, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 33.15799648506015
# Time = 133.58 sec
#
# [--] Toy 36:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2058, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 51.511337176523625
# Time = 143.26 sec
#
# [--] Toy 37:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2099, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 28.585250576945327
# Time = 111.86 sec
#
# [--] Toy 38:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2094, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 33.187742071848845
# Time = 117.63 sec
#
# [--] Toy 39:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2078, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 19.495621906074575
# Time = 114.81 sec
#
# [--] Toy 40:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2140, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 36.98700039818635
# Time = 148.76 sec
#
# [--] Toy 41:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2042, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.560769042984816
# Time = 121.78 sec
#
# [--] Toy 42:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2140, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 38.06561564479017
# Time = 163.24 sec
#
# [--] Toy 43:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2112, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 30.310972809401278
# Time = 101.68 sec
#
# [--] Toy 44:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2027, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 12.313436447378471
# Time = 175.25 sec
#
# [--] Toy 45:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2107, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 28.25891748164625
# Time = 167.13 sec
#
# [--] Toy 46:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2153, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 48.79958410377958
# Time = 163.12 sec
#
# [--] Toy 47:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2122, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 32.720818133767466
# Time = 161.66 sec
#
# [--] Toy 48:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2076, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 16.814180928066747
# Time = 160.8 sec
#
# [--] Toy 49:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2069, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 24.01559993535912
# Time = 159.28 sec

# %%
# in utils.py you additional functions can be found to plot the test statistics

plot_ref_data(ref=np.loadtxt('/content/t.txt',delimiter=',')[:,1], data=np.loadtxt('/content/runs/NP2/t.txt',delimiter=',')[:,1],
              name='NP2', out_path='./fig', title='T distribution (Reference-vs-NP2)', density=True, bins=10,
              c_ref='#abd9e9', e_ref='#2c7bb6', c_sig='#fdae61', e_sig='#d7191c')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-1c009910df80> in <module>
#       3 plot_ref_data(ref=np.loadtxt('/content/t.txt',delimiter=',')[:,1], data=np.loadtxt('/content/runs/NP2/t.txt',delimiter=',')[:,1],
#       4               name='NP2', out_path='./fig', title='T distribution (Reference-vs-NP2)', density=True, bins=10,
# ----> 5               c_ref='#abd9e9', e_ref='#2c7bb6', c_sig='#fdae61', e_sig='#d7191c')
#
# /content/utils.py in plot_ref_data(ref, data, name, dof, out_path, title, density, bins, c_ref, e_ref, c_sig, e_sig)
#     518
#     519     if out_path:
# --> 520         plt.savefig(out_path+"/refdata_{}.pdf".format(name), bbox_inches='tight')
#     521
#     522     plt.close()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata, **kwargs)
#    2539             file = filename._file
#    2540         else:
# -> 2541             file = PdfFile(filename, metadata=metadata)
#    2542         try:
#    2543             file.newPage(width, height)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     457         self.original_file_like = None
#     458         self.tell_base = 0
# --> 459         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     460         if not opened:
#     461             try:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './fig/refdata_NP2.pdf'

# %% [markdown]
# # NP3

# %%
N_0=200000 # size of reference sample
N0=2000 # expected background
weight=N0/N_0

M=3000
lam=1e-9
flk_sigma = 0.3

flk_config = get_logflk_config(M,flk_sigma,[lam],weight=weight,iter=[100],seed=None,cpu=True) # seed is set inside learn_t function

# null hypothesis
# NS=0 # expected NP component
# run_toys("NP0", "./reference/", N_0, N0, NS, flk_config, toys=np.arange(100), plots_freq=99, df=9.6)

# alternative hypothesis with NP3 signal
NS=90 # expected NP component
run_toys("NP3", "./NP3/", N_0, N0, NS, flk_config, toys=np.arange(50), plots_freq=49, df= best[0])
# Out:
# [--] Toy 0:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2084, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 26.100219205177012
# Time = 164.95 sec
# [--] Toy 1:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2086, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 34.85384008029271
# Time = 172.96 sec
#
# [--] Toy 2:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2068, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 23.70039574432758
# Time = 138.01 sec
#
# [--] Toy 3:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2025, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 29.568763577010074
# Time = 157.72 sec
#
# [--] Toy 4:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2218, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 46.1042828819987
# Time = 160.26 sec
#
# [--] Toy 5:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2133, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 26.981568761672406
# Time = 113.73 sec
#
# [--] Toy 6:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2091, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 19.609878123789997
# Time = 149.47 sec
#
# [--] Toy 7:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2114, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 34.29114277018596
# Time = 150.01 sec
#
# [--] Toy 8:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2078, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 36.05436563404922
# Time = 149.86 sec
#
# [--] Toy 9:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2151, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 55.617517210585106
# Time = 154.37 sec
#
# [--] Toy 10:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2209, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 51.414756124633186
# Time = 171.93 sec
#
# [--] Toy 11:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2035, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.74113935737101
# Time = 162.47 sec
#
# [--] Toy 12:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2041, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.59647556623672
# Time = 173.95 sec
#
# [--] Toy 13:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2157, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 37.6746390535705
# Time = 176.17 sec
#
# [--] Toy 14:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2145, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 22.919414036649925
# Time = 168.32 sec
#
# [--] Toy 15:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2111, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 15.189581941961194
# Time = 166.03 sec
#
# [--] Toy 16:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2083, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 16.212467059505315
# Time = 179.06 sec
#
# [--] Toy 17:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2144, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 23.71089126576777
# Time = 162.99 sec
#
# [--] Toy 18:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2071, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 27.9644890688474
# Time = 172.69 sec
#
# [--] Toy 19:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2073, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 8.169845366387335
# Time = 174.08 sec
#
# [--] Toy 20:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2047, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 16.17779052066598
# Time = 186.33 sec
#
# [--] Toy 21:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2135, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 33.19987929932256
# Time = 134.86 sec
#
# [--] Toy 22:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2057, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 19.686353507096925
# Time = 122.09 sec
#
# [--] Toy 23:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2103, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 13.461390076156476
# Time = 161.22 sec
#
# [--] Toy 24:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2070, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 27.663881441348906
# Time = 157.28 sec
#
# [--] Toy 25:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2031, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 34.3547937147707
# Time = 171.51 sec
#
# [--] Toy 26:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2071, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 19.472211283630855
# Time = 165.63 sec
#
# [--] Toy 27:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2103, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 28.20041319958915
# Time = 156.99 sec
#
# [--] Toy 28:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2151, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 35.30162392949319
# Time = 156.78 sec
#
# [--] Toy 29:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(1989, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 24.059964924927662
# Time = 172.98 sec
#
# [--] Toy 30:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2039, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 14.389446791089512
# Time = 120.85 sec
#
# [--] Toy 31:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2164, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 36.72194819347078
# Time = 163.78 sec
#
# [--] Toy 32:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2036, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 30.837418515296065
# Time = 155.66 sec
#
# [--] Toy 33:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2098, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 20.283170119706597
# Time = 169.14 sec
#
# [--] Toy 34:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2054, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 16.048289589498793
# Time = 159.04 sec
#
# [--] Toy 35:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2087, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 30.98857247545675
# Time = 155.62 sec
#
# [--] Toy 36:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2058, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 44.247372610955566
# Time = 162.11 sec
#
# [--] Toy 37:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2099, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 18.624685915734318
# Time = 149.36 sec
#
# [--] Toy 38:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2094, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 25.80355325140087
# Time = 159.9 sec
#
# [--] Toy 39:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2078, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 9.578265525227664
# Time = 159.55 sec
#
# [--] Toy 40:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2140, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 30.98165522468986
# Time = 144.62 sec
#
# [--] Toy 41:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2042, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 22.821585092684913
# Time = 117.64 sec
#
# [--] Toy 42:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2140, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 42.220743095844
# Time = 158.58 sec
#
# [--] Toy 43:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2112, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 34.56911235027266
# Time = 153.03 sec
#
# [--] Toy 44:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2027, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 21.291467423686306
# Time = 166.09 sec
#
# [--] Toy 45:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2107, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 22.144631035863995
# Time = 177.59 sec
#
# [--] Toy 46:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2153, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 54.59151801391653
# Time = 123.16 sec
#
# [--] Toy 47:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2122, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 25.38190558043766
# Time = 154.37 sec
#
# [--] Toy 48:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2076, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 10.45762559153522
# Time = 125.57 sec
#
# [--] Toy 49:
# [--] Reference shape:(200000, 1)
# [--] Data shape:(2069, 1)
# Iteration 0 - penalty 1.000000e-09 - sub-iterations 100
# t = 11.942271896271365
# Time = 119.65 sec

# %%
# in utils.py you additional functions can be found to plot the test statistics

plot_ref_data(ref=np.loadtxt('/content/t.txt',delimiter=',')[:,1], data=np.loadtxt('/content/runs/NP3/t.txt',delimiter=',')[:,1],
              name='NP3', out_path='./fig', title='T distribution (Reference-vs-NP3)', density=True, bins=10,
              c_ref='#abd9e9', e_ref='#2c7bb6', c_sig='#fdae61', e_sig='#d7191c')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-17178bc13055> in <module>
#       3 plot_ref_data(ref=np.loadtxt('/content/t.txt',delimiter=',')[:,1], data=np.loadtxt('/content/runs/NP3/t.txt',delimiter=',')[:,1],
#       4               name='NP3', out_path='./fig', title='T distribution (Reference-vs-NP3)', density=True, bins=10,
# ----> 5               c_ref='#abd9e9', e_ref='#2c7bb6', c_sig='#fdae61', e_sig='#d7191c')
#
# /content/utils.py in plot_ref_data(ref, data, name, dof, out_path, title, density, bins, c_ref, e_ref, c_sig, e_sig)
#     518
#     519     if out_path:
# --> 520         plt.savefig(out_path+"/refdata_{}.pdf".format(name), bbox_inches='tight')
#     521
#     522     plt.close()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata, **kwargs)
#    2539             file = filename._file
#    2540         else:
# -> 2541             file = PdfFile(filename, metadata=metadata)
#    2542         try:
#    2543             file.newPage(width, height)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     457         self.original_file_like = None
#     458         self.tell_base = 0
# --> 459         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     460         if not opened:
#     461             try:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './fig/refdata_NP3.pdf'
